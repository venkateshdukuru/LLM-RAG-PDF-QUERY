# %%
# Install necessary libraries
# !pip install langchain openai tiktoken rapidocr-onnxruntime PyMuPDF faiss-cpu

from google.colab import userdata
import os
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.2.2)
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.31.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (0.7.0)
# Requirement already satisfied: rapidocr-onnxruntime in /usr/local/lib/python3.10/dist-packages (1.3.22)
# Requirement already satisfied: PyMuPDF in /usr/local/lib/python3.10/dist-packages (1.24.5)
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.10/dist-packages (1.8.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.2.4)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.2.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.1.71)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.7.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.3.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2024.5.15)
# Requirement already satisfied: pyclipper>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from rapidocr-onnxruntime) (1.3.0.post5)
# Requirement already satisfied: opencv-python>=4.5.1.48 in /usr/local/lib/python3.10/dist-packages (from rapidocr-onnxruntime) (4.8.0.76)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from rapidocr-onnxruntime) (1.16.0)
# Requirement already satisfied: Shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from rapidocr-onnxruntime) (2.0.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rapidocr-onnxruntime) (9.4.0)
# Requirement already satisfied: onnxruntime>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from rapidocr-onnxruntime) (1.18.0)
# Requirement already satisfied: PyMuPDFb==1.24.3 in /usr/local/lib/python3.10/dist-packages (from PyMuPDF) (1.24.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.0->langchain) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.0->langchain) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.3)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.7.0->rapidocr-onnxruntime) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.7.0->rapidocr-onnxruntime) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.7.0->rapidocr-onnxruntime) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.7.0->rapidocr-onnxruntime) (1.12.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain) (2.4)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime>=1.7.0->rapidocr-onnxruntime) (10.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.7.0->rapidocr-onnxruntime) (1.3.0)

# %%
# Fetch OpenAI API key and set environment variable
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %%
# Data Ingestion
import fitz  # PyMuPDF
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
# Function to extract text from PDF
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    text = ""
    for page_num in range(len(doc)):
        page = doc.load_page(page_num)
        text += page.get_text()
    return text

# %%
# Path to your PDF file
pdf_path = "/content/data.pdf"

# %%
# Extract text from PDF
rawdata = extract_text_from_pdf(pdf_path)

# %%
# Split the extracted text into chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
text_chunks = text_splitter.split_text(rawdata)

# %%
# Convert text chunks into Document format required by FAISS
from langchain.docstore.document import Document

documents = [Document(page_content=chunk) for chunk in text_chunks]

print(documents)
# Out:
# [Document(page_content="6\x10\x14 _\x03%DQN\x03RI\x03WKH\x03:HVW\x030DUNHW\x10/LQNHG\x03&'V\n\x07\x15\x0f\x14\x1c\x1a\x0f\x13\x13\x13\x11\x13\x13\x03\x19\x10<($5\x030$5.(7\x10/,1.('\x03&(57,),&$7(6\x032)\x03'(326,7\x03/,1.('\x0372\x037+(\x03%13\x033$5,%$6\x03\n08/7,\x03$66(7\x03',9(56,),('\x03\x18\x03,1'(;\x03GXH\x030D\\\x03\x15\x1c\x0f\x03\x15\x13\x15\x19\n6XSSOHPHQW\x03GDWHG\x030D\\\x03\x15\x15\x0f\x03\x15\x13\x15\x13\x03WR\x03'LVFORVXUH\x036WDWHPHQW\x03GDWHG\x03)HEUXDU\\\x03\x14\x0f\x03\x15\x13\x15\x13\n7(506\n&'\x036800$5<\n,VVXHU\n%DQN\x03RI\x03WKH\x03:HVW\x0f\x036DQ\x03)UDQFLVFR\x0f\x03&DOLIRUQLD\n'HSRVLW\x03$PRXQW\n7KH\x03IDFH\x03DPRXQW\x03RI\x03WKH\x03&'\n0LQLPXP\x03\n'HQRPLQDWLRQV\n\x07\x14\x0f\x13\x13\x13\x11\x13\x13\x03DQG\x03LQFUHPHQWV\x03RI\x03\x07\x14\x0f\x13\x13\x13\x11\x13\x13\x03WKHUHDIWHU\n5HIHUHQFH\x03$VVHW\n7KH\x035HIHUHQFH\x03,QGH[\x03GHVFULEHG\x03KHUHLQ"), Document(page_content="7KH\x035HIHUHQFH\x03,QGH[\x03GHVFULEHG\x03KHUHLQ\n5HIHUHQFH\x03,QGH[\n%13\x033DULEDV\x030XOWL\x03$VVHW\x03'LYHUVLILHG \x18\x03,QGH[\x03\x0b%ORRPEHUJ\x03SDJH\x03\n\x05%13,0$'\x18\x05\x0c\n,QGH[\x03&RPSRQHQWV\n&RPSRQHQW\x03%13\x033DULEDV\x03,QGLFHV\n%13\x033DULEDV\x03(XUR]RQH\x03(TXLW\\\x03)XWXUHV\x03,QGH[\x03\x0b%ORRPEHUJ\x03SDJH\n\x05%13,)(8\x05\x0c\n%13\x033DULEDV\x0386\x03(TXLW\\\x03)XWXUHV\x03,QGH[\x03\x0b%ORRPEHUJ\x03SDJH\x03\x05%13,)86\x05\x0c\n%13\x033DULEDV\x03-DSDQ\x03(TXLW\\\x03)XWXUHV\x03,QGH[\x03\x0b%ORRPEHUJ\x03SDJH\x03\x05%13,)-3\x05\x0c\n%13\x033DULEDV\x03(85\x03\x14\x13<\x03)XWXUHV\x03,QGH[\x03\x0b%ORRPEHUJ\x03SDJH\x03\x05%13,)(\x14\x13\x05\x0c\n%13\x033DULEDV\x0386'\x03\x14\x13<\x03)XWXUHV\x03,QGH[\x03\x0b%ORRPEHUJ\x03SDJH\x03\x05%13,)8\x14\x13\x05"), Document(page_content="%13\x033DULEDV\x03-3<\x03\x14\x13<\x03)XWXUHV\x03,QGH[\x03\x0b%ORRPEHUJ\x03SDJH\x03\x05%13,)-\x14\x13\x05\x0c\n&RPSRQHQW\x03&RPPRGLW\\\x03,QGLFHV\n%ORRPEHUJ\x03&RPPRGLW\\\x03H[\x10$JULFXOWXUH\x03DQG\x03/LYHVWRFN\x03&DSSHG\x03,QGH[\n\x0b%ORRPEHUJ\x03SDJH\x03\x05%%8;$/&\x05\x0c\n6\t3\x03*6&,\x03*ROG\x03,QGH[\x03([FHVV\x035HWXUQ\x03\x0b%ORRPEHUJ\x03SDJH\x03\x0563*6*&3\x05\x0c\n5HGHPSWLRQ\x03$PRXQW\x03\nDW\x030DWXULW\\\n7KH\x03VXP\x03RI\x03WKH\x03'HSRVLW\x03$PRXQW\x03DQG\x03WKH\x03,QWHUHVW\x033D\\PHQW\x0f\x03LI\x03DQ\\\n,QWHUHVW\x033D\\PHQW\n7KH\x03'HSRVLW\x03$PRXQW\x03PXOWLSOLHG\x03E\\\x03WKH\x03JUHDWHU\x03RI\x03\x0b$\x0c\x03WKH\x030LQLPXP\x035HWXUQ\x03\nDQG\x03\x0b%\x0c\x03WKH\x03SURGXFW\x03RI\x03\x0b[\x0c\x03WKH\x033DUWLFLSDWLRQ\x035DWH\x03DQG\x03\x0b\\\x0c\x03WKH\x03)LQDO\x03,QGH[\x03"), Document(page_content="5HWXUQ\n0LQLPXP\x035HWXUQ\n\x13\x11\x13\x13\x08\n,QLWLDO\x03,QGH[\x03/HYHO\n7KH\x03&ORVLQJ\x03/HYHO\x03RI\x03WKH\x035HIHUHQFH\x03,QGH[\x03RQ\x03WKH\x03,QLWLDO\x039DOXDWLRQ\x03'DWH\n)LQDO\x03,QGH[\x03/HYHO\n7KH\x03&ORVLQJ\x03/HYHO\x03RI\x03WKH\x035HIHUHQFH\x03,QGH[\x03RQ\x03WKH\x039DOXDWLRQ\x03'DWH\n)LQDO\x03,QGH[\x035HWXUQ\n7KH\x03TXRWLHQW\x0f\x03H[SUHVVHG\x03DV\x03D\x03SHUFHQWDJH\x0f\x03RI\x03\x0b[\x0c\x03WKH\x03)LQDO\x03,QGH[\x03/HYHO\x03PLQXV\x03\nWKH\x03,QLWLDO\x03,QGH[\x03/HYHO\x0f\x03GLYLGHG\x03E\\\x03\x0b\\\x0c\x03WKH\x03,QLWLDO\x03,QGH[\x03/HYHO\n3DUWLFLSDWLRQ\x035DWH\n\x14\x13\x13\x11\x13\x13\x08\n)',&\x03,QVXUDQFH\n7KH\x03'HSRVLW\x03$PRXQW\x0f\x03WRJHWKHU\x03ZLWK\x03RWKHU\x03GHSRVLWV\x03ZLWK\x03WKH\x03%DQN\x03KHOG\x03LQ\x03"), Document(page_content="WKH\x03VDPH\x03ULJKW\x03DQG\x03FDSDFLW\\\x0f\x03LV\x03LQVXUHG E\\\x03WKH\x03)',&\x03XS\x03WR\x03WKH\x03DSSOLFDEOH\x03\n)',&\x03LQVXUDQFH\x03OLPLWV\x11\n&DOFXODWLRQ\x03$JHQW\n%DQN\x03RI\x03WKH\x03:HVW\x0f\x036DQ\x03)UDQFLVFR\x0f\x03&DOLIRUQLD\n&86,3\n\x13\x19\x17\x15\x19;+\x16\x1a\n&'\x036HULHV\x031XPEHU\n\x19\x16\x16\n&DOODEOH\x03E\\\x03,VVXHU\n,QDSSOLFDEOH\n(VWLPDWHG\x039DOXH\n\x07\x1c\x19\x18\x11\x1b\x13\n&RPPLVVLRQV\x03DQG\x03\n)HHV\n%13\x033DULEDV\x036HFXULWLHV\x03PD\\\x03SD\\\x03XS\x03WR\x03\x16\x11\x13\x13\x08\x03RI\x03WKH\x03'HSRVLW\x03$PRXQW\x03\x0bXS\x03WR\x03\n\x07\x16\x13\x03SHU\x03\x07\x14\x0f\x13\x13\x13\x11\x13\x13\x03'HSRVLW\x03$PRXQW\x0c\x03LQ\x03VHOOLQJ\x03FRPPLVVLRQV ...

# %%
pip install -U langchain-community
# Out:
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.10/dist-packages (0.2.2)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.6.6)
# Requirement already satisfied: langchain<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.2.2)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.2.4)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.1.71)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (1.25.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.3.0,>=0.2.0->langchain-community) (0.2.1)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain<0.3.0,>=0.2.0->langchain-community) (2.7.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.0->langchain-community) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.0->langchain-community) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (3.10.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (2024.2.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (4.12.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain-community) (2.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain-community) (2.18.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)

# %%
# Install FAISS and set up vector store
from langchain.vectorstores import FAISS
from langchain.prompts import ChatPromptTemplate

# %%
# Initialize OpenAI embeddings
from langchain.embeddings import OpenAIEmbeddings
embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)

vectorstore = FAISS.from_documents(documents, embeddings)
retriever = vectorstore.as_retriever()

# %%
# Create prompt template
template = """You are an assistant for question-answering tasks.
Use the following pieces of retrieved context to answer the question.
If you don't know the answer, just say that you don't know.
Use ten sentences maximum and keep the answer concise.
Question: {question}

Context: {context}

Answer:
"""

prompt = ChatPromptTemplate.from_template(template)

# %%
# Handle deprecation warnings and set up chat model
from langchain.chat_models import ChatOpenAI
llm_model = ChatOpenAI(openai_api_key=OPENAI_API_KEY, model_name="gpt-3.5-turbo")

# %%
# Output parser
from langchain.schema.output_parser import StrOutputParser
output_parser = StrOutputParser()

# %%
# Create RAG chain
from langchain.schema.runnable import RunnablePassthrough

rag_chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt
    | llm_model
    | output_parser
)

# %%
# Invoke RAG chain with sample questions
print(rag_chain.invoke("What is the Cusip in the document?"))
# Out:
# The CUSIP in the document is 40434YQJ9.

# %%
rag_chain.invoke("Who is the Issuer of this document?")
# Out:
# 'The Issuer of this document is HSBC Bank USA, National Association.'

# %%
rag_chain.invoke("Can you tell me the name of the Issuer mentioned in this document?")
# Out:
# 'The Issuer mentioned in the document is HSBC Bank USA, National Association.'
